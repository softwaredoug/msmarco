# %%
from msmarco.download import minimarco
from time import perf_counter
import numpy as np
import pandas as pd
from msmarco.evaluate import grade_results, judge_queries

REBUILD=False
NUM_QUERIES = 1000

# %%
minim, minim_judgments = minimarco(size=NUM_QUERIES, rebuild=REBUILD)
minim
# Out:
#         msmarco_id                                                url  \
# 0          D312959        https://en.wikipedia.org/wiki/Visual_cortex
# 1          D140227  http://www.webmd.com/depression/electroconvuls...
# 2          D213890              https://en.wikipedia.org/wiki/Cholera
# 3         D1033338  https://answers.yahoo.com/question/index?qid=2...
# 4          D508131          http://www.healthline.com/health/beriberi
# ...            ...                                                ...
# 2304559   D1794588          https://rsvpify.com/wedding-rsvp-wording/
# 1261480    D528885                       http://www.hemlockgorge.org/
# 894047    D2027801         http://www.youtube.com/watch?v=utPqPCw8S00
# 3035513   D1019218  https://www.merriam-webster.com/dictionary/pos...
# 1048778   D1343236         http://www.youtube.com/watch?v=zUGHClYmgBY
#
#                                                      title  \
# 0                                            Visual cortex
# 1                          Electroconvulsive Therapy (ECT)
# 2                                                  Cholera
# 3        The ABO blood type system in humans is an exam...
# 4                                        What is beriberi?
# ...                                                    ...
# 2304559  Wedding RSVP Wording Ideas and Format â 2017 E...
# 1261480                                      Hemlock Gorge
# 894047                  Easy Tricks That Build Calves Fast
# 3035513                                           position
# 1048778                    Star Tours (On-Ride) Disneyland
#
#                                                       body
# 0        From Wikipedia, the free encyclopedianavigatio...
# 1        Electroconvulsive Therapy (ECT)Treatment Overv...
# 2        From Wikipedia, the free encyclopedianavigatio...
# 3        Science & Mathematics Biology The ABO blood ty...
# 4        What is beriberi? Beriberi is a disease caused...
# ...                                                    ...
# 2304559  April 20, 2017Wedding RSVP Wording Ideas and F...
# 1261480  Welcometo the Home Page of the Friends of Heml...
# 894047   Easy Tricks That Build Calves Fast Seniority H...
# 3035513  1positionnoun po·si·tion \ pə-ˈzi-shən \Popula...
# 1048778  Star Tours (On-Ride) Disneyland Sharp Producti...
#
# [10984 rows x 4 columns]

# %%
minim_judgments
# Out:
#      query_id                                              query msmarco_id
# 0           3     another name for the primary visual cortex is     D312959
# 1           5               ect is a treatment that is used for     D140227
# 2          12   rice-water stools are associated with disease...    D213890
# 3          15               the abo blood types are examples of    D1033338
# 4          16             the vitamin that prevents beriberi is     D508131
# ..        ...                                                ...        ...
# 995      4806                     ketamine infusion side effects    D806650
# 996      4810                 kirby puckett baseball cards value    D999913
# 997      4811  klinefelter syndrome is an consequence of what...    D732799
# 998      4826                                    lasa catagories   D1424340
# 999      4829                       lgps definition final salary    D853632
#
# [1000 rows x 3 columns]

# %%
from searcharray import SearchArray
from msmarco.tokenizers import snowball_tokenizer

minim['title_snowball'] = SearchArray.index(minim['title'], tokenizer=snowball_tokenizer)
minim['body_snowball'] = SearchArray.index(minim['body'], tokenizer=snowball_tokenizer)

minim
# Out:
#         msmarco_id                                                url  \
# 0          D312959        https://en.wikipedia.org/wiki/Visual_cortex
# 1          D140227  http://www.webmd.com/depression/electroconvuls...
# 2          D213890              https://en.wikipedia.org/wiki/Cholera
# 3         D1033338  https://answers.yahoo.com/question/index?qid=2...
# 4          D508131          http://www.healthline.com/health/beriberi
# ...            ...                                                ...
# 2304559   D1794588          https://rsvpify.com/wedding-rsvp-wording/
# 1261480    D528885                       http://www.hemlockgorge.org/
# 894047    D2027801         http://www.youtube.com/watch?v=utPqPCw8S00
# 3035513   D1019218  https://www.merriam-webster.com/dictionary/pos...
# 1048778   D1343236         http://www.youtube.com/watch?v=zUGHClYmgBY
#
#                                                      title  \
# 0                                            Visual cortex
# 1                          Electroconvulsive Therapy (ECT)
# 2                                                  Cholera
# 3        The ABO blood type system in humans is an exam...
# 4                                        What is beriberi?
# ...                                                    ...
# 2304559  Wedding RSVP Wording Ideas and Format â 2017 E...
# 1261480                                      Hemlock Gorge
# 894047                  Easy Tricks That Build Calves Fast
# 3035513                                           position
# 1048778                    Star Tours (On-Ride) Disneyland
#
#                                                       body  \
# 0        From Wikipedia, the free encyclopedianavigatio...
# 1        Electroconvulsive Therapy (ECT)Treatment Overv...
# 2        From Wikipedia, the free encyclopedianavigatio...
# 3        Science & Mathematics Biology The ABO blood ty...
# 4        What is beriberi? Beriberi is a disease caused...
# ...                                                    ...
# 2304559  April 20, 2017Wedding RSVP Wording Ideas and F...
# 1261480  Welcometo the Home Page of the Friends of Heml...
# 894047   Easy Tricks That Build Calves Fast Seniority H...
# 3035513  1positionnoun po·si·tion \ pə-ˈzi-shən \Popula...
# 1048778  Star Tours (On-Ride) Disneyland Sharp Producti...
#
#                                             title_snowball  \
# 0                              Terms({'cortex', 'visual'})
# 1              Terms({'ect', 'electroconvuls', 'therapi'})
# 2                                       Terms({'cholera'})
# 3        Terms({'blood', 'the', 'is', 'system', 'exampl...
# 4                        Terms({'is', 'what', 'beriberi'})
# ...                                                    ...
# 2304559  Terms({'2017', 'and', 'format', 'word', 'â', '...
# 1261480                         Terms({'gorg', 'hemlock'})
# 894047   Terms({'calv', 'easi', 'that', 'trick', 'build...
# 3035513                                   Terms({'posit'})
# 1048778     Terms({'tour', 'disneyland', 'onrid', 'star'})
#
#                                              body_snowball
# 0        Terms({'between', 'neurophysiolog', 'orm', 'wi...
# 1        Terms({'physiolog', 'onlin', 'effect', 'than',...
# 2        Terms({'74', 'between', 'accept', 'snow', 'mic...
# 3        Terms({'onlin', 'websit', 'polymorph', 'type',...
# 4        Terms({'doe', 'type', 'purchas', 'high', 'is',...
# ...                                                    ...
# 2304559  Terms({'20', '2017', 'and', '2017wed', 'format...
# 1261480  Terms({'between', 'written', 'mile', 'declar',...
# 894047   Terms({'i', 'isnt', 'if', 'excus', 'consist', ...
# 3035513  Terms({'between', 'brace', 'snow', 'slavon', '...
# 1048778  Terms({'lightyear', 'pari', 'views840star', 'd...
#
# [10984 rows x 6 columns]

# %%
def or_query_search(corpus, fields, query, query_id=None, n=10):
    if not isinstance(fields, list):
        fields = [fields]
    start = perf_counter()
    scored = np.zeros(len(corpus))
    for field in fields:
        boost = 1.0
        if '^' in field:
            field, boost = field.split('^')
            boost = float(boost)
        tokenizer = corpus[field].array.tokenizer
        tokens = tokenizer(query)
        scored += (np.sum([corpus[field].array.score(token) for token in tokens], axis=0) * boost)
    took = perf_counter() - start
    
    top_n_idx = np.argsort(scored)[::-1][:n]
    scores = scored[top_n_idx]
    top_n_idx, scores

    top_n = corpus[['title', 'msmarco_id']].iloc[top_n_idx]
    top_n['scores'] = scores
    top_n['query'] = query
    top_n['query_id'] = query_id
    top_n['took'] = took
    top_n['rank'] = np.arange(n) + 1
    return top_n

or_query_search(corpus=minim, fields="title_snowball", query="cheese inside")
# Out:
#                                                   title msmarco_id    scores  \
# 2206782                                  Shaking Inside    D272394  4.525233
# 741051                                    SMOKED CHEESE   D2825273  3.958058
# 2475345                  Renal-safe Macaroni and Cheese   D3471613  3.275180
# 1406053                  Philly Cheese Steak Sandwiches   D3143895  3.275180
# 1057881  Inside Airbnbâs New San Francisco Headquarters   D2596811  3.193526
# 2751295        Inside Kelly Ayotte's fight for survival   D3164816  3.193526
# 2752904            Vegan Cashew Cheese (Stupidly Easy!)   D2949551  3.015085
# 562        Do Milk, Cheese & Yogurt Have Carbohydrates?   D1324826  2.793262
# 2322190          Calories in Salami and Cheese Sandwich   D1985612  2.793262
# 1209870              9 cheeses not made from cow's milk   D3083621  2.601841
#
#                  query query_id      took  rank
# 2206782  cheese inside     None  0.001534     1
# 741051   cheese inside     None  0.001534     2
# 2475345  cheese inside     None  0.001534     3
# 1406053  cheese inside     None  0.001534     4
# 1057881  cheese inside     None  0.001534     5
# 2751295  cheese inside     None  0.001534     6
# 2752904  cheese inside     None  0.001534     7
# 562      cheese inside     None  0.001534     8
# 2322190  cheese inside     None  0.001534     9
# 1209870  cheese inside     None  0.001534    10

# %% [markdown]
# ## Title search
#
# Just search title w/ BM25

# %%
results = []

for idx, row in minim_judgments.iterrows():
    top_n = or_query_search(corpus=minim, fields='title_snowball', query=row['query'], query_id=row['query_id'])
    results.append(top_n)

results = pd.concat(results)
results
# Out:
#                                       title msmarco_id    scores  \
# 0                             Visual cortex    D312959  9.712187
# 2688513  What is another word for pen name?    D255020  7.039500
# 698775          Search for another ZIP Code   D3441318  4.661566
# 150233                 primary productivity    D962942  4.525233
# 957                    Visual communication    D999777  4.294182
# ...                                     ...        ...       ...
# 3169074                       MALAWI SALARY   D2922025  3.187463
# 2147546                  Paralegal Salaries   D1992342  3.187463
# 2602680                          Definition   D1039622  2.958066
# 688                              Definition     D90500  2.958066
# 3125338                          Definition   D3288006  2.958066
#
#                                                    query  query_id      took  \
# 0         another name for the primary visual cortex is          3  0.002098
# 2688513   another name for the primary visual cortex is          3  0.002098
# 698775    another name for the primary visual cortex is          3  0.002098
# 150233    another name for the primary visual cortex is          3  0.002098
# 957       another name for the primary visual cortex is          3  0.002098
# ...                                                  ...       ...       ...
# 3169074                     lgps definition final salary      4829  0.000679
# 2147546                     lgps definition final salary      4829  0.000679
# 2602680                     lgps definition final salary      4829  0.000679
# 688                         lgps definition final salary      4829  0.000679
# 3125338                     lgps definition final salary      4829  0.000679
#
#          rank
# 0           1
# 2688513     2
# 698775      3
# 150233      4
# 957         5
# ...       ...
# 3169074     6
# 2147546     7
# 2602680     8
# 688         9
# 3125338    10
#
# [10000 rows x 7 columns]

# %%
graded = grade_results(minim_judgments, results)
queries_judged = judge_queries(graded)
queries_judged.sum() / NUM_QUERIES
# Out:
# 0.5511444444444444

# %% [markdown]
# ## Body search

# %%
results = []

for idx, row in minim_judgments.iterrows():
    top_n = or_query_search(corpus=minim, fields='body_snowball', query=row['query'], query_id=row['query_id'])
    results.append(top_n)

results = pd.concat(results)
results
# Out:
#                                                 title msmarco_id     scores  \
# 0                                       Visual cortex    D312959  11.593686
# 1564008                                             .   D1874002   8.299027
# 823875                    What happens when we dream?   D1613253   7.705410
# 927              Brain Structures and their Functions     D10666   7.391504
# 820415                         Does Color Even Exist?   D2894277   7.121673
# ...                                               ...        ...        ...
# 1725040                            Total Remuneration   D1876162   4.485892
# 2628376  ALTER TABLE Statement (Microsoft Access SQL)   D2995855   4.384942
# 211                                    27th amendment   D1601407   4.321597
# 1476878                      Escrow Assistant  Salary   D2992688   4.319798
# 968477                                 Cost of Living   D1497157   4.187379
#
#                                                    query  query_id      took  \
# 0         another name for the primary visual cortex is          3  0.017785
# 1564008   another name for the primary visual cortex is          3  0.017785
# 823875    another name for the primary visual cortex is          3  0.017785
# 927       another name for the primary visual cortex is          3  0.017785
# 820415    another name for the primary visual cortex is          3  0.017785
# ...                                                  ...       ...       ...
# 1725040                     lgps definition final salary      4829  0.000887
# 2628376                     lgps definition final salary      4829  0.000887
# 211                         lgps definition final salary      4829  0.000887
# 1476878                     lgps definition final salary      4829  0.000887
# 968477                      lgps definition final salary      4829  0.000887
#
#          rank
# 0           1
# 1564008     2
# 823875      3
# 927         4
# 820415      5
# ...       ...
# 1725040     6
# 2628376     7
# 211         8
# 1476878     9
# 968477     10
#
# [10000 rows x 7 columns]

# %%
graded = grade_results(minim_judgments, results)
queries_judged = judge_queries(graded)
queries_judged.sum() / NUM_QUERIES
# Out:
# 0.778593253968254

# %% [markdown]
# ## Body plus title
#
# Body and title together

# %%
results = []

for idx, row in minim_judgments.iterrows():
    top_n = or_query_search(corpus=minim,
                            fields=['body_snowball', 'title_snowball'], query=row['query'], query_id=row['query_id'])
    results.append(top_n)

results = pd.concat(results)
results
# Out:
#                                       title msmarco_id     scores  \
# 0                             Visual cortex    D312959  21.305873
# 2688513  What is another word for pen name?    D255020   9.537623
# 1872315    What is the name of C# compiler?   D3298785   9.115857
# 957                    Visual communication    D999777   8.916365
# 1564008                                   .   D1874002   8.299027
# ...                                     ...        ...        ...
# 42                             MSL Salaries   D3049251   6.449042
# 2147546                  Paralegal Salaries   D1992342   6.399776
# 825              Nursing Salary Information     D11799   6.175322
# 12090              Start salary sacrificing     D93188   6.157456
# 1788256         Court Administrator  Salary   D1832941   6.081524
#
#                                                    query  query_id      took  \
# 0         another name for the primary visual cortex is          3  0.021036
# 2688513   another name for the primary visual cortex is          3  0.021036
# 1872315   another name for the primary visual cortex is          3  0.021036
# 957       another name for the primary visual cortex is          3  0.021036
# 1564008   another name for the primary visual cortex is          3  0.021036
# ...                                                  ...       ...       ...
# 42                          lgps definition final salary      4829  0.001575
# 2147546                     lgps definition final salary      4829  0.001575
# 825                         lgps definition final salary      4829  0.001575
# 12090                       lgps definition final salary      4829  0.001575
# 1788256                     lgps definition final salary      4829  0.001575
#
#          rank
# 0           1
# 2688513     2
# 1872315     3
# 957         4
# 1564008     5
# ...       ...
# 42          6
# 2147546     7
# 825         8
# 12090       9
# 1788256    10
#
# [10000 rows x 7 columns]

# %%
graded = grade_results(minim_judgments, results)
queries_judged = judge_queries(graded)
queries_judged.sum() / NUM_QUERIES
# Out:
# 0.7801968253968253

# %% [markdown]
# ## Weigh body * 10

# %%
results = []

for idx, row in minim_judgments.iterrows():
    top_n = or_query_search(corpus=minim,
                            fields=['body_snowball^10', 'title_snowball'], query=row['query'], query_id=row['query_id'])
    results.append(top_n)

results = pd.concat(results)
graded = grade_results(minim_judgments, results)
queries_judged = judge_queries(graded)
queries_judged.sum() / NUM_QUERIES

# %% [markdown]
# ## Weigh title * 10

# %%
results = []

for idx, row in minim_judgments.iterrows():
    top_n = or_query_search(corpus=minim,
                            fields=['body_snowball', 'title_snowball^10'], query=row['query'], query_id=row['query_id'])
    results.append(top_n)

results = pd.concat(results)
graded = grade_results(minim_judgments, results)
queries_judged = judge_queries(graded)
queries_judged.sum() / NUM_QUERIES

# %% [markdown]
# ## Compare MSMarco -> MiniMarco Sample

# %%
minmarco_mrr10 = np.asarray([0.5511444444444444, 0.778593253968254, 0.7801968253968253, 0.8076515873015874, 0.5958305555555555])
msmarco_mrr100 = np.asarray([0.1914920634920635, 0.22227182539682536, 0.26367896825396825, 0.2569694444444444, 0.20999087301587302])

# %%
msmarco_sorted_idx = msmarco_mrr100.argsort()

# %%
msmarco_mrr100_sorted = msmarco_mrr100[msmarco_sorted_idx]
minimarco_mrr10_sorted = minmarco_mrr10[msmarco_sorted_idx]

# %%
from scipy.stats import spearmanr

spearmanr(msmarco_mrr100_sorted, minimarco_mrr10_sorted)

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.12.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.4/165.4 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages (from scipy) (1.26.4)
# Downloading scipy-1.12.0-cp311-cp311-macosx_12_0_arm64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 18.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.12.0
