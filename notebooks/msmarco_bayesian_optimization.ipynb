# %%
import numpy as np
import pandas as pd
from msmarco.index import indexed
from msmarco.evaluate import grade_results, judge_queries
from time import perf_counter
from searcharray.similarity import bm25_similarity, classic_similarity, default_bm25
from searcharray import SetOfResults
# 50 QPS: 0.4783807889536503
NUM_QUERIES = 1000
# Out:
# /var/folders/c3/6754bm4d6cv9n0k3v04lx53h0000gq/T/ipykernel_13262/1838799328.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Will take a min or two to load, and a good hour to build an index first time
msmarco = indexed()

# %%
msmarco.memory_usage()
# Out:
# Index                 132
# msmarco_id       25710680
# url              25710680
# title            25710680
# body_idx      44433766928
# title_idx       325609656
# dtype: int64

# %%
import math

def convert_size(size_bytes):
    if size_bytes == 0:
        return "0B"
    size_name = ("B", "KB", "MB", "GB", "TB", "PB", "EB", "ZB", "YB")
    i = int(math.floor(math.log(size_bytes, 1024)))
    p = math.pow(1024, i)
    s = round(size_bytes / p, 2)
    return "%s %s" % (s, size_name[i])
    
def term_hist():
    print("Num Terms: ", len(msmarco['body_idx'].array.posns.encoded_term_posns))
    hist = []
    for i in range(0, 1000):
        term = msmarco['body_idx'].array.term_dict.get_term(i)
        docfreq = msmarco['body_idx'].array.docfreq(term)
        roaring_len = len(msmarco['body_idx'].array.posns.encoded_term_posns[i])
        hist.append( (i, term, docfreq, roaring_len) )
    
    hist.sort(key=lambda row: row[-1], reverse=True)
    
    for i in range(0,100):
        ratio = hist[i][3] / hist[i][2]
        print(f"{hist[i][0]} -- term:{hist[i][1]} | docfreq:{hist[i][2]} | bytes:{convert_size(8 * hist[i][3])} | ratio:{ratio}")

# %%
np.sort(msmarco['body_idx'].array.score('cheese'))
# Out:
# array([0.       , 0.       , 0.       , ..., 4.7565475, 5.0600863,
#        8.568701 ], dtype=float32)

# %%
from searcharray.solr import edismax

edismax(msmarco, q='cheese curds',
        qf=['title_idx', 'body_idx'],
        mm=2,
        tie=0.2,
        pf='title_idx')
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  '((title_idx:chees^1 | body_idx:chees^1) (title_idx:curd^1 | body_idx:curd^1))~2 (title_idx:"chees curd")^1')

# %%
# %%prun

def search(corpus, fields, query, query_id=None,
           pf2_fields=None,
           pf_fields=None,
           tie=0,
           mm=1,
           n=10, 
           similarities=default_bm25):
    if not isinstance(fields, list):
        fields = [fields]

    start = perf_counter()
    scored, explain = edismax(msmarco,
                              q=query,
                              qf=fields,
                              tie=tie,
                              pf=pf_fields)
                              # pf2=pf2_fields)
                              # mm=mm,
                              # similarity=similarities)
    # print(f"q={query} | qf={fields} | tie {tie} | pf={pf_fields} | pf2={pf2_fields} | mm={mm}")
    # print(explain)
    took = perf_counter() - start

    metadata = {
        'took': took,
        'query_id': query_id
    }
    return scored, n, query, metadata

search(corpus=msmarco, fields=["title_idx^10", "body_idx"], query="Adjustable-rate mortgage", n=100)[0]
# results.get_all()
# Out:
# array([ 1.02253187,  0.        ,  0.        , ...,  0.        ,
#         0.        , 21.14721298])

# %%
from msmarco.evaluate import grade_results, judgments, msmarco_of_ids

msmarco_judgments = judgments().sample(NUM_QUERIES)
# ids = set(msmarco_judgments['msmarco_id'].tolist())
# msmarco_for_judgments = msmarco_of_ids(ids)
# msmarco_judgments = msmarco_judgments.merge(pd.DataFrame(msmarco_for_judgments), how='left', on='msmarco_id')
#print(msmarco_judgments.columns)
#msmarco_of_ids
# msmarco_judgments

# %%
import random

def random_probes(features, num_probes=10, feature_ranges={}):
    
    probes = []
    for _ in range(num_probes):
        param_dict = {}
        for param in features:
            if param in feature_ranges:
                param_dict[param] = random.uniform(feature_ranges[param][0],
                                                   feature_ranges[param][1])
            else:
                param_dict[param] = random.random() * 10
        probes.append(param_dict)
    return pd.DataFrame(probes)

probes = random_probes(features=['title_boost', 'body_boost',
                                 'title_pf_boost', 'body_pf_boost',
                                 'title_pf2_boost', 'body_pf2_boost',
                                 'tie', 'mm',
                                 'k1_title', 'b_title',
                                 'k1_body', 'b_body'],
                       feature_ranges={'k1_title': (0.1,3.0),
                                       'tie': (0,1),
                                       'mm': (0,100)})
probes
# Out:
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     0.144830    6.580237        8.543714       9.398618         6.684248
# 1     1.903217    6.245112        9.907438       7.306416         7.701440
# 2     5.714221    7.964295        9.060951       2.481385         3.962330
# 3     6.898372    7.293533        6.999836       6.145602         8.310750
# 4     6.194621    2.798459        1.545713       7.048738         3.295889
# 5     8.090880    6.193140        8.741100       7.103978         3.517253
# 6     0.173212    6.428415        2.731204       1.304548         8.008149
# 7     6.381746    2.385828        9.467746       8.308390         3.936380
# 8     7.206995    0.508757        1.442996       8.696361         8.885449
# 9     2.607193    8.721340        4.169124       9.543435         3.365047
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body    b_body
# 0        1.466168  0.224425  56.060055  1.500000  2.531442  2.562167  5.882268
# 1        7.066172  0.384687  61.366408  1.921138  8.721453  5.344916  8.557910
# 2        2.309485  0.664829  73.887717  1.231645  3.540308  2.780652  4.376089
# 3        5.251827  0.077337  10.787573  1.717216  0.745594  6.727299  4.494990
# 4        6.289102  0.920098  12.364705  2.845301  4.444710  8.039117  0.415203
# 5        2.178450  0.032010  27.064394  2.115338  3.555533  0.898519  5.865027
# 6        1.700908  0.453777  70.412339  1.011466  7.710929  9.565844  7.496094
# 7        9.238335  0.072889  15.824271  1.190511  8.813057  3.117686  2.190659
# 8        6.090403  0.570837  65.176586  1.332333  2.006784  4.023760  4.023903
# 9        6.892572  0.586623  67.072434  0.727796  8.118343  6.545738  1.627235

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

executor = ThreadPoolExecutor()

def run_all(corpus, judgments, fields, pf_fields, pf2_fields,
            tie=0, mm=1,
            max_posns=None, min_posns=None, similarities=default_bm25, n=10):
    results = []
    query_no = 0
    results = SetOfResults(msmarco)
    futures = []
    for idx, row in judgments.iterrows():
        futures.append(executor.submit(search,
                                       corpus=corpus,
                                       fields=fields,
                                       pf_fields=pf_fields,
                                       pf2_fields=pf2_fields,
                                       similarities=similarities,
                                       n=n,
                                       query=row['query'],
                                       query_id=row['query_id']))
    start = perf_counter()
    for future in as_completed(futures):
        scored, n, query, metadata = future.result()
        results.ins_top_n(scored, N=n, query=query, metadata=metadata)
        if query_no > 0 and query_no % 50 == 0:
            print(f"-- {query_no} QPS: {query_no / (perf_counter() - start)} q:{query}")
        query_no += 1
    results = results.get_all()
    graded = grade_results(msmarco_judgments, results)
    print("Random search complete")
    return graded

def run_with_params(params,
                    msmarco,
                    msmarco_judgments,
                    n=100):
    bm25_similarity_title = bm25_similarity(b=params['b_title'],
                                            k1=params['k1_title'])
    bm25_similarity_body = bm25_similarity(b=params['b_body'],
                                           k1=params['k1_body'])
    fields = [f"title_idx^{params['title_boost']}", f"body_idx^{params['body_boost']}"]
    pf_fields = [f"title_idx^{params['title_pf_boost']}", f"body_idx^{params['body_pf_boost']}"]
    pf2_fields = [f"title_idx^{params['title_pf2_boost']}", f"body_idx^{params['body_pf2_boost']}"]
    mm=f"{int(params['mm'])}%"

    similarities = {"title_idx": bm25_similarity_title,
                    "body_idx": bm25_similarity_body}

    results = run_all(msmarco,
                      msmarco_judgments,
                      fields=fields,
                      pf2_fields=pf2_fields,
                      pf_fields=pf_fields,
                      mm=mm,
                      tie=params['tie'],
                      n=100,
                      similarities=similarities)
    return results, params

# %% [markdown]
# ## Random search param
#
# Seed the search with a random search

# %%
from random import uniform

def random_search(msmarco, msmarco_judgments, 
                  features, feature_ranges={}, times=1):
    
    results = []
    futures = []
    all_graded = None

    params = random_probes(features, feature_ranges=feature_ranges, num_probes=times)
    print(params)

    print(f"Random search over {len(params)}")
    for _, row in params.iterrows():
        graded, params = run_with_params(row, msmarco, msmarco_judgments,
                                         n=100)
        if all_graded is None:
            all_graded = graded.copy().groupby(['query'])['reciprical_rank'].first()
        else:
            all_graded += graded.copy().groupby(['query'])['reciprical_rank'].first()
        queries_judged = judge_queries(graded)
        mrr = queries_judged.sum() / len(msmarco_judgments)

        result_dict = {param_name: params[param_name] for param_name in features} 
        result_dict['mrr100'] = mrr
        results.append(result_dict)

    return pd.DataFrame(results), all_graded

initial_probes, query_perfs = random_search(msmarco, msmarco_judgments.sample(50),
                                            features=['title_boost', 'body_boost',
                                                       'title_pf_boost', 'body_pf_boost',
                                                       'title_pf2_boost', 'body_pf2_boost',
                                                       'mm', 'tie',
                                                       'k1_title', 'b_title',
                                                       'k1_body', 'b_body'])
# Out:
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     2.247152    5.852672        4.553634       6.562009          1.91965
#
#    body_pf2_boost        mm       tie  k1_title   b_title  k1_body   b_body
# 0        9.226755  8.708589  3.373431  4.944802  6.760062  0.12533  5.26955
# Random search over 1
# Random search complete

# %%
query_perfs.sort_values()
# Out:
# query
# cast of grace and frankie                                      0.0
# what happens low mean platelet volume                          0.0
# what is a doghouse                                             0.0
# what is a logistics company                                    0.0
# what is a personal assistant job description                   0.0
# what is a retarder                                             0.0
# what is inulin?                                                0.0
# what is reversible myocardial ischemia                         0.0
# what is stout mean                                             0.0
# what is the routing number for td bank ma                      0.0
# what is wcm server                                             0.0
# what nationality is the name graves                            0.0
# what network is bob's burgers on                               0.0
# what team's theme is sweet caroline                            0.0
# what temperature should chicken be smoked                      0.0
# what's the difference between a lake and sea                   0.0
# when does arkansas football play texas again                   0.0
# when should i start giving my baby water                       0.0
# when was the final star placed on the flag                     0.0
# where is darien illinois                                       0.0
# where is hallmark movie enchanted christmas filmed             0.0
# which scientist played a role in developing the cell theory    0.0
# what does the word sarcophagus mean                            0.0
# who is yolanda hadid husband                                   0.0
# what does exceeding fierce mean                                0.0
# what are the benefits of getting the bird flu vaccine          0.0
# concho address                                                 0.0
# define molasses                                                0.0
# how do baboons adapt                                           0.0
# how long does it take to cook fish on a cedar plank            0.0
# how long for parakeet to lay egg                               0.0
# how long is a cow gestation period                             0.0
# how long stool samples good for fridge                         0.0
# how much do passports cost?                                    0.0
# how much will tile for my basement cost                        0.0
# how to get boyfriend to vacate my house                        0.0
# inflamed bowel disease                                         0.0
# is geographic tongue rare                                      0.0
# is icloud drive unlimited storage                              0.0
# is login a noun                                                0.0
# is the heritage language similar to the second language?       0.0
# lean manufacturing definition of waste                         0.0
# microtransaction definition                                    0.0
# normal prostate size by age                                    0.0
# side effects for efudex                                        0.0
# temperature in santa rosa calif                                0.0
# initial cost of sewage treatment plant                         0.0
# why are isocost straight lines                                 0.0
# what are the two forms of democracy                            1.0
# what is the chuck e cheese rats name                           1.0
# Name: reciprical_rank, dtype: float64

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
import pandas as pd

y_train = initial_probes['mrr100']
x_train = initial_probes.drop('mrr100', axis=1)


gpr = GaussianProcessRegressor()
gpr.fit(x_train.to_numpy(), y_train.to_numpy())
# Out:
# GaussianProcessRegressor()

# %%
x_train
# Out:
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     2.247152    5.852672        4.553634       6.562009          1.91965
#
#    body_pf2_boost        mm       tie  k1_title   b_title  k1_body   b_body
# 0        9.226755  8.708589  3.373431  4.944802  6.760062  0.12533  5.26955

# %% [markdown]
# ### Score probes

# %%
probes
# Out:
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     0.144830    6.580237        8.543714       9.398618         6.684248
# 1     1.903217    6.245112        9.907438       7.306416         7.701440
# 2     5.714221    7.964295        9.060951       2.481385         3.962330
# 3     6.898372    7.293533        6.999836       6.145602         8.310750
# 4     6.194621    2.798459        1.545713       7.048738         3.295889
# 5     8.090880    6.193140        8.741100       7.103978         3.517253
# 6     0.173212    6.428415        2.731204       1.304548         8.008149
# 7     6.381746    2.385828        9.467746       8.308390         3.936380
# 8     7.206995    0.508757        1.442996       8.696361         8.885449
# 9     2.607193    8.721340        4.169124       9.543435         3.365047
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body    b_body
# 0        1.466168  0.224425  56.060055  1.500000  2.531442  2.562167  5.882268
# 1        7.066172  0.384687  61.366408  1.921138  8.721453  5.344916  8.557910
# 2        2.309485  0.664829  73.887717  1.231645  3.540308  2.780652  4.376089
# 3        5.251827  0.077337  10.787573  1.717216  0.745594  6.727299  4.494990
# 4        6.289102  0.920098  12.364705  2.845301  4.444710  8.039117  0.415203
# 5        2.178450  0.032010  27.064394  2.115338  3.555533  0.898519  5.865027
# 6        1.700908  0.453777  70.412339  1.011466  7.710929  9.565844  7.496094
# 7        9.238335  0.072889  15.824271  1.190511  8.813057  3.117686  2.190659
# 8        6.090403  0.570837  65.176586  1.332333  2.006784  4.023760  4.023903
# 9        6.892572  0.586623  67.072434  0.727796  8.118343  6.545738  1.627235

# %%
from scipy.stats import norm

def score_probes(gpr, probes, best_mrr, theta):
    predictions, std_devs = gpr.predict(probes, return_std=True)
    
    probes["prediction"] = predictions
    probes["std_dev"] = std_devs
        
    probes['opportunity'] = probes['prediction'] - best_mrr - theta
    probes['prob_of_improvement'] = norm.cdf( probes['opportunity'] / probes['std_dev'])
    
    return probes.sort_values('prob_of_improvement', ascending=False)

score_probes(gpr, probes.copy(), best_mrr=1.0, theta=0.9)
# Out:
# /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GaussianProcessRegressor was fitted without feature names
#   warnings.warn(
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     0.144830    6.580237        8.543714       9.398618         6.684248
# 1     1.903217    6.245112        9.907438       7.306416         7.701440
# 2     5.714221    7.964295        9.060951       2.481385         3.962330
# 3     6.898372    7.293533        6.999836       6.145602         8.310750
# 4     6.194621    2.798459        1.545713       7.048738         3.295889
# 5     8.090880    6.193140        8.741100       7.103978         3.517253
# 6     0.173212    6.428415        2.731204       1.304548         8.008149
# 7     6.381746    2.385828        9.467746       8.308390         3.936380
# 8     7.206995    0.508757        1.442996       8.696361         8.885449
# 9     2.607193    8.721340        4.169124       9.543435         3.365047
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 0        1.466168  0.224425  56.060055  1.500000  2.531442  2.562167
# 1        7.066172  0.384687  61.366408  1.921138  8.721453  5.344916
# 2        2.309485  0.664829  73.887717  1.231645  3.540308  2.780652
# 3        5.251827  0.077337  10.787573  1.717216  0.745594  6.727299
# 4        6.289102  0.920098  12.364705  2.845301  4.444710  8.039117
# 5        2.178450  0.032010  27.064394  2.115338  3.555533  0.898519
# 6        1.700908  0.453777  70.412339  1.011466  7.710929  9.565844
# 7        9.238335  0.072889  15.824271  1.190511  8.813057  3.117686
# 8        6.090403  0.570837  65.176586  1.332333  2.006784  4.023760
# 9        6.892572  0.586623  67.072434  0.727796  8.118343  6.545738
#
#      b_body     prediction  std_dev  opportunity  prob_of_improvement
# 0  5.882268   0.000000e+00      1.0         -1.9             0.028717
# 1  8.557910   0.000000e+00      1.0         -1.9             0.028717
# 2  4.376089   0.000000e+00      1.0         -1.9             0.028717
# 3  4.494990   2.628025e-68      1.0         -1.9             0.028717
# 4  0.415203   5.700236e-63      1.0         -1.9             0.028717
# 5  5.865027  9.517250e-167      1.0         -1.9             0.028717
# 6  7.496094   0.000000e+00      1.0         -1.9             0.028717
# 7  2.190659   1.215384e-72      1.0         -1.9             0.028717
# 8  4.023903   0.000000e+00      1.0         -1.9             0.028717
# 9  1.627235   0.000000e+00      1.0         -1.9             0.028717

# %% [markdown]
# ### Bayesian search loop

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

def search_w_prob_params(probes, msmarco_judgments):
    results = []
    query_perfs = None
    for idx, row in probes.iterrows():
        graded, params = run_with_params(row, msmarco,
                                         msmarco_judgments, 100)
        if query_perfs is None:
            query_perfs = graded.copy().groupby(['query'])['reciprical_rank'].first()
        else:
            query_perfs += graded.copy().groupby(['query'])['reciprical_rank'].first()

        queries_judged = judge_queries(graded)
        mrr = queries_judged.sum() / len(msmarco_judgments)

        result_dict = {'mrr100': mrr}
        for param, value in params.items():
            result_dict[param] = value
        results.append(result_dict)
        print(result_dict['mrr100'], result_dict)
    return pd.DataFrame(results), query_perfs

# %%
SEED=100
NUM_QUERIES=1000
FEATURES = ['title_boost', 'body_boost',
            'title_pf_boost', 'body_pf_boost',
            'title_pf2_boost', 'body_pf2_boost',
            'tie', 'mm',
            'k1_title', 'b_title',
            'k1_body', 'b_body']
PICKLE_PATH = f"~/.msmarco/msmarco_bayes_probes_{len(FEATURES)}_{NUM_QUERIES}_{SEED}.pkl"

def bayesian_search(initial_probes, 
                    msmarco_judgments,
                    feature_ranges,
                    theta=1.2,
                    rounds=10,
                    num_probes=4):
    probes = initial_probes.copy()
    initial_cols = initial_probes.columns
    features = initial_probes.drop('mrr100', axis=1).columns
    print(features)
    query_perfs = None
    for _ in range(rounds):
        y_train = probes['mrr100']
        x_train = probes.drop('mrr100', axis=1)
        x_train = probes[features]
        
        gpr = GaussianProcessRegressor()
        gpr.fit(x_train.to_numpy(), y_train.to_numpy())

        new_probes = random_probes(x_train.columns,
                                   num_probes=100, 
                                   feature_ranges=feature_ranges)
        new_probes = score_probes(gpr, new_probes,
                                  best_mrr=probes['mrr100'].max(),
                                  theta=theta)
        new_probes = new_probes[:num_probes]
        print(new_probes.sort_values('prob_of_improvement', ascending=False))
        new_probes, round_query_perfs = search_w_prob_params(new_probes, msmarco_judgments)

        if query_perfs is None:
            query_perfs = round_query_perfs
        else:
            query_perfs += round_query_perfs

        # Concat, dropping scoring, etc
        probes = pd.concat([new_probes, probes])
        probes = probes[initial_cols]
        print(len(probes))
        print("CURRENT RESULTS")
        print(probes.sort_values('mrr100', ascending=False))
        print("WORST QUERIES")
        print(query_perfs.sort_values(ascending=False).head(10))
        print("BEST QUERIES")
        print(query_perfs.sort_values(ascending=True).head(10))
        probes.to_pickle(PICKLE_PATH)
    return probes

probes = None
try:
    probes = pd.read_pickle(PICKLE_PATH)
    print("Loaded ", PICKLE_PATH)
    print(probes)
except FileNotFoundError:
    print(f"No probes file found at {PICKLE_PATH}, starting with random search")
    pass

# Run with 1000 queries
msmarco_judgments = judgments().sample(NUM_QUERIES, random_state=SEED)
print("Random search")
feature_ranges={'k1_title': (0.1,3.0),
            'b_title':  (0.1,3.0),
            'k1_body': (0.1,3.0),
            'b_body':  (0.1,3.0),
            'tie': (0,1.0),
            'mm': (25,100)
            }
initial_probes, query_perfs = random_search(msmarco,
                                            msmarco_judgments,
                                            features=['title_boost', 'body_boost',
                                                      'title_pf_boost', 'body_pf_boost',
                                                      'title_pf2_boost', 'body_pf2_boost',
                                                      'tie', 'mm',
                                                      'k1_title', 'b_title',
                                                      'k1_body', 'b_body'],
                                            feature_ranges=feature_ranges,
                                            times=5)

print(query_perfs)
print(initial_probes)

if probes is not None:
    probes = pd.concat([probes, initial_probes])
else:
    probes = initial_probes

results = bayesian_search(probes,
                          msmarco_judgments,
                          feature_ranges=feature_ranges)
results.sort_values('mrr100', ascending=False)
# Out:
# No probes file found at ~/.msmarco/msmarco_bayes_probes_12_1000_100.pkl, starting with random search
# Random search
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body    b_body
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451  0.654765
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639  2.684080
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360  2.678514
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830  0.911157
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328  0.324970
# Random search over 5
# -- 50 QPS: 3.3712763842228997 q:what nationality is the name d'elia
# -- 100 QPS: 2.9605125723215324 q:quarter hours equal semester hours
# -- 150 QPS: 3.1178889937422385 q:how many seats one candidate can contest
# -- 200 QPS: 3.204108337599597 q:what is esoteric
# -- 250 QPS: 3.161101732780732 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.126209733261216 q:in medical terms what does htn stand for
# -- 350 QPS: 3.103187066610139 q:is nugenix harmful
# -- 400 QPS: 3.10541794408162 q:what is gpra
# -- 450 QPS: 3.122259231887595 q:do you keep olive oil in the refrigerator
# -- 500 QPS: 3.1644775521653563 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.1264272621497198 q:how big do kumquats trees get
# -- 600 QPS: 3.1148231676904814 q:biggest fish market in the world
# -- 650 QPS: 3.14055320029619 q:what does ftd stand for flowers
# -- 700 QPS: 3.1451711591625044 q:who invented the first steam engine what year
# -- 750 QPS: 3.0908292004004596 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.0880916299540955 q:what river flows through pine falls
# -- 850 QPS: 3.0609245141446833 q:what is autonomic regulation
# -- 900 QPS: 3.0087911717158415 q:causes of ostomy drainage
# -- 950 QPS: 3.0214483450336775 q:where is sargasso sea located
# Random search complete
# -- 50 QPS: 3.290689462337712 q:what nationality is the name d'elia
# -- 100 QPS: 3.120302555144987 q:which kind of stroke occurs when an artery supplying blood is blocked by a blood clot?
# -- 150 QPS: 3.2971195610909647 q:allsports physiotherapy cost of appointment
# -- 200 QPS: 3.3629616372473925 q:can you measure adh levels
# -- 250 QPS: 3.2800915936410218 q:where do bot fly live
# -- 300 QPS: 3.227898238135344 q:what is a plantar release?
# -- 350 QPS: 3.1987386112435376 q:is rheumatoid arthritis same as arthritis
# -- 400 QPS: 3.209797252392916 q:what is gpra
# -- 450 QPS: 3.229274906017272 q:how to find mean of grouped data
# -- 500 QPS: 3.2633987524578805 q:who owns prosight insurance
# -- 550 QPS: 3.242890808738227 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.2144301483847455 q:what is a superscript
# -- 650 QPS: 3.237437887123608 q:when an atom gains or loses a valence electron it becomes a charged particle called
# -- 700 QPS: 3.23435969470532 q:what to bake cupcake in
# -- 750 QPS: 3.1683679733900965 q:world's largest ikea store
# -- 800 QPS: 3.1462757815223186 q:is the marines part of the navy?
# -- 850 QPS: 3.1405325911889026 q:what type of baggage fees does frontier have
# -- 900 QPS: 3.0744340221493536 q:causes of both feet numbness
# -- 950 QPS: 3.0724244322432717 q:what is below rib cage
# Random search complete
# -- 50 QPS: 3.325626517127684 q:what nationality is the name d'elia
# -- 100 QPS: 3.165222614450419 q:quarter hours equal semester hours
# -- 150 QPS: 3.327562950959576 q:most common language in india
# -- 200 QPS: 3.3767546508461357 q:what happens after the option period
# -- 250 QPS: 3.2935766446608103 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.250385647974427 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.2256549684636355 q:is nugenix harmful
# -- 400 QPS: 3.2603541402169296 q:how long should u wait to roll the window down after tenting
# -- 450 QPS: 3.2817194704809958 q:do you keep olive oil in the refrigerator
# -- 500 QPS: 3.3207650263899815 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.2862672486480524 q:which vitamins are leached out when the foods they contain are cooked in liquid
# -- 600 QPS: 3.258887774740412 q:what are buprenorphine
# -- 650 QPS: 3.277279452148075 q:what does ftd stand for flowers
# -- 700 QPS: 3.2731912611913345 q:how does the international space station orbits the earth
# -- 750 QPS: 3.208106788327568 q:world's largest ikea store
# -- 800 QPS: 3.2083466410424384 q:labradoodle price range
# -- 850 QPS: 3.189279768597057 q:how long are flights from new york to london
# -- 900 QPS: 3.137648706715825 q:causes of both feet numbness
# -- 950 QPS: 3.15355738511801 q:what is below rib cage
# Random search complete
# -- 50 QPS: 3.283053784202359 q:what nationality is the name d'elia
# -- 100 QPS: 3.1758494308508576 q:what does beat feet mean
# -- 150 QPS: 3.311844299781355 q:how many seats one candidate can contest
# -- 200 QPS: 3.364962834280069 q:can you measure adh levels
# -- 250 QPS: 3.2828509661539296 q:what are argentina's cowboys called?
# -- 300 QPS: 3.229014193685286 q:meaning of name olav
# -- 350 QPS: 3.2233600377121348 q:is nugenix harmful
# -- 400 QPS: 3.247492475257522 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2665966528209722 q:is quartz a silicate or oxide
# -- 500 QPS: 3.2928364284224507 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.2816203858650055 q:what is a layperson
# -- 600 QPS: 3.263180292951006 q:who is thomas nast?
# -- 650 QPS: 3.2718845224588957 q:what does ftd stand for flowers
# -- 700 QPS: 3.259801905441667 q:how does the international space station orbits the earth
# -- 750 QPS: 3.2004208914855425 q:world's largest ikea store
# -- 800 QPS: 3.1928439926413783 q:is the marines part of the navy?
# -- 850 QPS: 3.1761351655652694 q:what type of baggage fees does frontier have
# -- 900 QPS: 3.140202976969763 q:causes of ostomy drainage
# -- 950 QPS: 3.132680156132359 q:what is below rib cage
# Random search complete
# -- 50 QPS: 3.2556948770095477 q:initial hiv symptoms
# -- 100 QPS: 3.2181947246093783 q:what does beat feet mean
# -- 150 QPS: 3.34405345526533 q:how many seats one candidate can contest
# -- 200 QPS: 3.4040866068228377 q:what is esoteric
# -- 250 QPS: 3.3189225182586197 q:what are argentina's cowboys called?
# -- 300 QPS: 3.272009792357062 q:in medical terms what does htn stand for
# -- 350 QPS: 3.2507131309981863 q:is nugenix harmful
# -- 400 QPS: 3.280736222752704 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2928711043577708 q:how to find mean of grouped data
# -- 500 QPS: 3.320989584960363 q:who owns prosight insurance
# -- 550 QPS: 3.307473350964908 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.289448712768222 q:what are buprenorphine
# -- 650 QPS: 3.3069451090705955 q:where is dhabeji in pakistan
# -- 700 QPS: 3.283784560251674 q:how does the international space station orbits the earth
# -- 750 QPS: 3.2205565669456533 q:what is tsh results
# -- 800 QPS: 3.2044498796160372 q:is the marines part of the navy?
# -- 850 QPS: 3.1828805715351827 q:how long do stitches take to heal
# -- 900 QPS: 3.141973237622553 q:causes of both feet numbness
# -- 950 QPS: 3.1454076024058475 q:how do i move a picture to facebook
# Random search complete
# query
# act test definition                                0.0
# adjunct pay columbia college pay                   0.0
# admin assistant job description                    0.0
# advantra medicare phone number                     0.0
# advert meaning                                     5.0
#                                                   ...
# why was the ponte vecchio bridge spared in wwii    0.0
# will store bought rose bush grow                   0.0
# world's largest ikea store                         0.0
# xml dtd what does the ? mean                       0.0
# zip code fairfield area                            0.0
# Name: reciprical_rank, Length: 1000, dtype: float64
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328
#
#      b_body    mrr100
# 0  0.654765  0.118431
# 1  2.684080  0.206245
# 2  2.678514  0.198330
# 3  0.911157  0.212266
# 4  0.324970  0.209227
# Index(['title_boost', 'body_boost', 'title_pf_boost', 'body_pf_boost',
#        'title_pf2_boost', 'body_pf2_boost', 'tie', 'mm', 'k1_title', 'b_title',
#        'k1_body', 'b_body'],
#       dtype='object')
#     title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 2      8.231969    8.310064        3.223559       2.288182         1.316251
# 6      0.513954    1.498232        4.719863       3.006974         5.486878
# 84     7.699919    3.572103        3.609991       5.200210         4.540570
# 88     1.399232    3.391308        6.524227       0.270131         4.398592
#
#     body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 2         8.560379  0.165337  81.438655  2.484507  0.787729  1.990831
# 6         5.194726  0.590494  82.452931  1.968564  1.110398  2.619814
# 84        7.178768  0.090383  59.637596  0.521740  0.816092  1.189236
# 88        6.166562  0.864784  89.674619  0.867954  0.457633  2.359540
#
#       b_body    prediction  std_dev  opportunity  prob_of_improvement
# 2   0.941007  3.775106e-07      1.0    -1.412266             0.078936
# 6   1.148325  5.424340e-10      1.0    -1.412266             0.078936
# 84  1.699714  5.200509e-11      1.0    -1.412266             0.078936
# 88  0.534347  3.717838e-11      1.0    -1.412266             0.078936
# /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GaussianProcessRegressor was fitted without feature names
#   warnings.warn(
# -- 50 QPS: 3.2399416989412964 q:initial hiv symptoms
# -- 100 QPS: 3.149342560372667 q:quarter hours equal semester hours
# -- 150 QPS: 3.3405647280353743 q:most common language in india
# -- 200 QPS: 3.397463813102319 q:what is esoteric
# -- 250 QPS: 3.3154251729633244 q:what are argentina's cowboys called?
# -- 300 QPS: 3.2438025010959843 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.241784784305303 q:is nugenix harmful
# -- 400 QPS: 3.2642858132928563 q:why is the holocaust unique
# -- 450 QPS: 3.28286447571143 q:how to find mean of grouped data
# -- 500 QPS: 3.3097874666811986 q:how much does it cost for a license plate
# -- 550 QPS: 3.294827296600765 q:what is a layperson
# -- 600 QPS: 3.2675126263177177 q:what are buprenorphine
# -- 650 QPS: 3.289749952733438 q:when an atom gains or loses a valence electron it becomes a charged particle called
# -- 700 QPS: 3.289562116312458 q:what to bake cupcake in
# -- 750 QPS: 3.2084684006956667 q:what does the term buttercup mean
# -- 800 QPS: 3.2044911547132395 q:labradoodle price range
# -- 850 QPS: 3.191634892168444 q:what is autonomic regulation
# -- 900 QPS: 3.1417851448693526 q:when was germany divided wwii
# -- 950 QPS: 3.1455278948231165 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.17817980802227948 {'mrr100': 0.17817980802227948, 'title_boost': 8.231968866844875, 'body_boost': 8.310063671796094, 'title_pf_boost': 3.2235593155141196, 'body_pf_boost': 2.2881819461807296, 'title_pf2_boost': 1.3162514788762791, 'body_pf2_boost': 8.560378788407654, 'tie': 0.16533656848097844, 'mm': 81.43865499294103, 'k1_title': 2.484507054138972, 'b_title': 0.7877294897447679, 'k1_body': 1.9908310170188392, 'b_body': 0.9410068733844694, 'prediction': 3.7751062522600654e-07, 'std_dev': 0.9999999999983248, 'opportunity': -1.4122655192649456, 'prob_of_improvement': 0.07893589751997432}
# -- 50 QPS: 3.2414434187136925 q:what nationality is the name d'elia
# -- 100 QPS: 3.1794339797425186 q:quarter hours equal semester hours
# -- 150 QPS: 3.3229686801850415 q:most common language in india
# -- 200 QPS: 3.4027651638365057 q:can you measure adh levels
# -- 250 QPS: 3.3122870211466333 q:what are argentina's cowboys called?
# -- 300 QPS: 3.255484654498027 q:symptoms of a vaginal yeast infection
# -- 350 QPS: 3.234513164828794 q:is nugenix harmful
# -- 400 QPS: 3.260485675155442 q:what is gpra
# -- 450 QPS: 3.2857552604811957 q:how to find mean of grouped data
# -- 500 QPS: 3.3144393698713124 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.306664381180736 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.2756630850226154 q:what are buprenorphine
# -- 650 QPS: 3.289597118335023 q:when an atom gains or loses a valence electron it becomes a charged particle called
# -- 700 QPS: 3.2879325257108207 q:types candy coated licorice
# -- 750 QPS: 3.219473390887596 q:what does the term buttercup mean
# -- 800 QPS: 3.2164448047376064 q:labradoodle price range
# -- 850 QPS: 3.187405040231441 q:what is autonomic regulation
# -- 900 QPS: 3.15274818931504 q:causes of ostomy drainage
# -- 950 QPS: 3.162868598292777 q:what is below rib cage
# Random search complete
# 0.12747897259125407 {'mrr100': 0.12747897259125407, 'title_boost': 0.5139537953718398, 'body_boost': 1.4982318221265878, 'title_pf_boost': 4.71986280761311, 'body_pf_boost': 3.0069735803274886, 'title_pf2_boost': 5.4868775750942085, 'body_pf2_boost': 5.194726280866407, 'tie': 0.590494120383597, 'mm': 82.45293069812678, 'k1_title': 1.9685644656140349, 'b_title': 1.110398188627478, 'k1_body': 2.619813637926258, 'b_body': 1.1483247203634859, 'prediction': 5.424339591765539e-10, 'std_dev': 1.0, 'opportunity': -1.412265896233137, 'prob_of_improvement': 0.0789358420429595}
# -- 50 QPS: 3.1624984107434675 q:initial hiv symptoms
# -- 100 QPS: 3.134913097290451 q:how many expresso beans equals one shot of expeesso
# -- 150 QPS: 3.341117713803198 q:most common language in india
# -- 200 QPS: 3.4010420074233214 q:can you measure adh levels
# -- 250 QPS: 3.3079449659838978 q:what are argentina's cowboys called?
# -- 300 QPS: 3.2565545066056263 q:meaning of name olav
# -- 350 QPS: 3.2415166750429063 q:is nugenix harmful
# -- 400 QPS: 3.2582935510396798 q:weather around the state of iowa
# -- 450 QPS: 3.284749662535234 q:what is bicarbonate in blood
# -- 500 QPS: 3.311265659965627 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.289912816401408 q:which vitamins are leached out when the foods they contain are cooked in liquid
# -- 600 QPS: 3.255017555927633 q:what are buprenorphine
# -- 650 QPS: 3.2723579871283057 q:when was the last total solar eclipse in az
# -- 700 QPS: 3.2786812985608687 q:who invented the first steam engine what year
# -- 750 QPS: 3.229798598439127 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.216146991340947 q:what to eat after donating blood
# -- 850 QPS: 3.1828890982587006 q:how long are flights from new york to london
# -- 900 QPS: 3.1583717696455262 q:causes of ostomy drainage
# -- 950 QPS: 3.162338211843363 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.21244047030892702 {'mrr100': 0.21244047030892702, 'title_boost': 7.699918683861643, 'body_boost': 3.5721034049275824, 'title_pf_boost': 3.609991220830283, 'body_pf_boost': 5.200209503230946, 'title_pf2_boost': 4.540570215252359, 'body_pf2_boost': 7.178767946457559, 'tie': 0.09038309635451225, 'mm': 59.63759617971732, 'k1_title': 0.5217403562664114, 'b_title': 0.8160918564026839, 'k1_body': 1.1892360449834305, 'b_body': 1.699714447819045, 'prediction': 5.2005089280551125e-11, 'std_dev': 1.0, 'opportunity': -1.4122658967235657, 'prob_of_improvement': 0.07893584197078451}
# -- 50 QPS: 3.2212245107986854 q:initial hiv symptoms
# -- 100 QPS: 3.1479630005604884 q:what does beat feet mean
# -- 150 QPS: 3.3129057935845783 q:most common language in india
# -- 200 QPS: 3.3659043576386622 q:can you measure adh levels
# -- 250 QPS: 3.299033596244867 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.228304244967859 q:symptoms of a vaginal yeast infection
# -- 350 QPS: 3.226879923273645 q:is nugenix harmful
# -- 400 QPS: 3.245645780988477 q:how long should u wait to roll the window down after tenting
# -- 450 QPS: 3.2551756928743396 q:how to find mean of grouped data
# -- 500 QPS: 3.2978685052141246 q:how much does it cost for a license plate
# -- 550 QPS: 3.275857391271604 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.2422104969567744 q:did panic at the disco break up
# -- 650 QPS: 3.260171240485044 q:what does ftd stand for flowers
# -- 700 QPS: 3.2545526446628816 q:types candy coated licorice
# -- 750 QPS: 3.1981369445119556 q:world's largest ikea store
# -- 800 QPS: 3.200608293734619 q:labradoodle price range
# -- 850 QPS: 3.1671689783172807 q:how to how to get accreditation
# -- 900 QPS: 3.1376446001544482 q:when was germany divided wwii
# -- 950 QPS: 3.14139125686752 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.10991683061523323 {'mrr100': 0.10991683061523323, 'title_boost': 1.399232218204458, 'body_boost': 3.3913082786089777, 'title_pf_boost': 6.524226904895459, 'body_pf_boost': 0.27013067959437254, 'title_pf2_boost': 4.398591694407919, 'body_pf2_boost': 6.166562016796106, 'tie': 0.8647837673192659, 'mm': 89.67461920207839, 'k1_title': 0.8679537380464769, 'b_title': 0.4576330667833661, 'k1_body': 2.359540182446599, 'b_body': 0.5343468743726801, 'prediction': 3.7178377749907915e-11, 'std_dev': 1.0, 'opportunity': -1.4122658967383925, 'prob_of_improvement': 0.07893584196860237}
# 9
# CURRENT RESULTS
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 2     7.699919    3.572103        3.609991       5.200210         4.540570
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 0     8.231969    8.310064        3.223559       2.288182         1.316251
# 1     0.513954    1.498232        4.719863       3.006974         5.486878
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 3     1.399232    3.391308        6.524227       0.270131         4.398592
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 2        7.178768  0.090383  59.637596  0.521740  0.816092  1.189236
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360
# 0        8.560379  0.165337  81.438655  2.484507  0.787729  1.990831
# 1        5.194726  0.590494  82.452931  1.968564  1.110398  2.619814
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451
# 3        6.166562  0.864784  89.674619  0.867954  0.457633  2.359540
#
#      b_body    mrr100
# 2  1.699714  0.212440
# 3  0.911157  0.212266
# 4  0.324970  0.209227
# 1  2.684080  0.206245
# 2  2.678514  0.198330
# 0  0.941007  0.178180
# 1  1.148325  0.127479
# 0  0.654765  0.118431
# 3  0.534347  0.109917
# WORST QUERIES
# query
# how many types of dances are there                                                     4.0
# causes of pseudohypoparathyroidism                                                     4.0
# what is benzenoid structure                                                            4.0
# where is dhabeji in pakistan                                                           4.0
# where is cvirte.dll located                                                            4.0
# types candy coated licorice                                                            4.0
# function of skin cells                                                                 4.0
# what is soft fraud                                                                     4.0
# us embassy manila phone number                                                         4.0
# when an atom gains or loses a valence electron it becomes a charged particle called    4.0
# Name: reciprical_rank, dtype: float64
# BEST QUERIES
# query
# act test definition                                     0.0
# what is an example of an adverb                         0.0
# what is an ima                                          0.0
# what is an insurance affidavit                          0.0
# what is an irony                                        0.0
# what is an rt                                           0.0
# what is an rtc module                                   0.0
# what is angkor wat, located in present-day cambodia?    0.0
# what is annual value                                    0.0
# what is another word for boosted                        0.0
# Name: reciprical_rank, dtype: float64
#     title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 86     2.802984    3.351903        5.546569       1.834426         8.073953
# 56     8.655626    6.004394        2.991956       6.085950         5.097607
# 40     4.431765    2.884621        7.415769       3.293152         4.505541
# 87     6.920996    8.326694        7.663800       9.547533         1.807249
#
#     body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 86        1.924414  0.716069  86.624643  1.050007  2.257546  2.012478
# 56        9.496163  0.212207  59.139499  0.775124  1.127936  2.479405
# 40        0.556615  0.750314  86.256875  0.324273  1.877960  1.902642
# 87        4.301109  0.363984  26.166670  2.386858  2.107418  1.675472
#
#       b_body    prediction  std_dev  opportunity  prob_of_improvement
# 86  0.339866  5.027919e-05      1.0    -1.412390             0.078918
# 56  0.243869  2.776973e-05      1.0    -1.412413             0.078914
# 40  1.853077  2.426194e-05      1.0    -1.412416             0.078914
# 87  0.457169  9.805252e-09      1.0    -1.412440             0.078910
# /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GaussianProcessRegressor was fitted without feature names
#   warnings.warn(
# -- 50 QPS: 3.184412707400696 q:define pop culture
# -- 100 QPS: 3.089873843422982 q:quarter hours equal semester hours
# -- 150 QPS: 3.27165168751632 q:most common language in india
# -- 200 QPS: 3.3580604605057593 q:what is rras
# -- 250 QPS: 3.2782450228376647 q:what are argentina's cowboys called?
# -- 300 QPS: 3.231441790748525 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.223665899098221 q:is nugenix harmful
# -- 400 QPS: 3.2511082507343136 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2676788495218805 q:how to find mean of grouped data
# -- 500 QPS: 3.3059761310713265 q:how much does it cost for a license plate
# -- 550 QPS: 3.2835848667200715 q:which dynasty started the great wall of china
# -- 600 QPS: 3.2630119682914414 q:what are buprenorphine
# -- 650 QPS: 3.2699150559137613 q:what does ftd stand for flowers
# -- 700 QPS: 3.2704891574326886 q:types candy coated licorice
# -- 750 QPS: 3.2004101736757296 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.2059846923132294 q:labradoodle price range
# -- 850 QPS: 3.1837592927680856 q:how long are flights from new york to london
# -- 900 QPS: 3.139956100620401 q:causes of both feet numbness
# -- 950 QPS: 3.1464366578595633 q:what is below rib cage
# Random search complete
# 0.1591948036035855 {'mrr100': 0.1591948036035855, 'title_boost': 2.802984409419691, 'body_boost': 3.3519034052303898, 'title_pf_boost': 5.546569298849398, 'body_pf_boost': 1.8344263721310239, 'title_pf2_boost': 8.073952805768918, 'body_pf2_boost': 1.924413614264483, 'tie': 0.716069164661676, 'mm': 86.62464262312287, 'k1_title': 1.0500071354984781, 'b_title': 2.2575455051849898, 'k1_body': 2.0124784594806933, 'b_body': 0.3398662831044682, 'prediction': 5.02791896163143e-05, 'std_dev': 0.9999999719465672, 'opportunity': -1.4123901911193106, 'prob_of_improvement': 0.07891754568957837}
# -- 50 QPS: 3.253699393168235 q:graduate mechanical engineer starting salary
# -- 100 QPS: 3.145840727860603 q:what does beat feet mean
# -- 150 QPS: 3.328883343773054 q:what year did draft numbering begin
# -- 200 QPS: 3.380208558614145 q:what is rras
# -- 250 QPS: 3.29465965190515 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.2310164511873602 q:temecula education complex in temecula
# -- 350 QPS: 3.222780296824833 q:is rheumatoid arthritis same as arthritis
# -- 400 QPS: 3.2439544013381987 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2665417225948277 q:is quartz a silicate or oxide
# -- 500 QPS: 3.288627123263288 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.274189032526512 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.253029169720032 q:what is a superscript
# -- 650 QPS: 3.2743010430954613 q:when an atom gains or loses a valence electron it becomes a charged particle called
# -- 700 QPS: 3.2636996856939695 q:types candy coated licorice
# -- 750 QPS: 3.209658859223904 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.2039553929436693 q:labradoodle price range
# -- 850 QPS: 3.181157249129521 q:how long are flights from new york to london
# -- 900 QPS: 3.1452961666005614 q:when was germany divided wwii
# -- 950 QPS: 3.1389944305314765 q:what is below rib cage
# Random search complete
# 0.21160312748793786 {'mrr100': 0.21160312748793786, 'title_boost': 8.655625895217756, 'body_boost': 6.004394071273417, 'title_pf_boost': 2.9919564510547536, 'body_pf_boost': 6.085950083759352, 'title_pf2_boost': 5.097607062928853, 'body_pf2_boost': 9.496162874107512, 'tie': 0.21220719141179034, 'mm': 59.139498968246045, 'k1_title': 0.7751242264874539, 'b_title': 1.1279355691274884, 'k1_body': 2.4794052088828566, 'b_body': 0.2438689983596445, 'prediction': 2.776972907345814e-05, 'std_dev': 0.9999999914564418, 'opportunity': -1.4124127005798535, 'prob_of_improvement': 0.07891423772430411}
# -- 50 QPS: 3.241864460627051 q:what nationality is the name d'elia
# -- 100 QPS: 3.10970067751077 q:how many expresso beans equals one shot of expeesso
# -- 150 QPS: 3.281541116280064 q:most common language in india
# -- 200 QPS: 3.372731621373189 q:can you measure adh levels
# -- 250 QPS: 3.2918783056316823 q:where do bot fly live
# -- 300 QPS: 3.2370055568418166 q:the agreement over how states would be represented in congress was known as the
# -- 350 QPS: 3.223400508681802 q:is nugenix harmful
# -- 400 QPS: 3.2399667480510588 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2580567938924085 q:do you keep olive oil in the refrigerator
# -- 500 QPS: 3.2957701654701577 q:how much does it cost for a license plate
# -- 550 QPS: 3.2691371136377385 q:what is a layperson
# -- 600 QPS: 3.2479243485859204 q:biggest fish market in the world
# -- 650 QPS: 3.263398439780978 q:descent with modification
# -- 700 QPS: 3.255818982971487 q:who invented the first steam engine what year
# -- 750 QPS: 3.193642472988914 q:world's largest ikea store
# -- 800 QPS: 3.182905934190122 q:is the marines part of the navy?
# -- 850 QPS: 3.1649019227846393 q:how to how to get accreditation
# -- 900 QPS: 3.122759423269307 q:causes of both feet numbness
# -- 950 QPS: 3.120455605139347 q:what is below rib cage
# Random search complete
# 0.21556256612932886 {'mrr100': 0.21556256612932886, 'title_boost': 4.431764574017904, 'body_boost': 2.884620822982721, 'title_pf_boost': 7.415769036148415, 'body_pf_boost': 3.2931523585649947, 'title_pf2_boost': 4.505541130130691, 'body_pf2_boost': 0.5566153846601074, 'tie': 0.7503142677069127, 'mm': 86.2568749418125, 'k1_title': 0.3242732136684278, 'b_title': 1.877959956695095, 'k1_body': 1.9026418921853465, 'b_body': 1.8530774224650068, 'prediction': 2.4261942869970383e-05, 'std_dev': 0.9999999934677815, 'opportunity': -1.412416208366057, 'prob_of_improvement': 0.07891372201957403}
# -- 50 QPS: 3.2032188505582475 q:what nationality is the name d'elia
# -- 100 QPS: 3.1203202833703707 q:what does beat feet mean
# -- 150 QPS: 3.2825793048511813 q:what pokemon do you get in omega ruby
# -- 200 QPS: 3.3777691626757966 q:what is esoteric
# -- 250 QPS: 3.2874177558547273 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.22523131712745 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.224471802612986 q:what makes infection around teeth
# -- 400 QPS: 3.2520139027570365 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2707336109226985 q:what is bicarbonate in blood
# -- 500 QPS: 3.2934372754758487 q:what makes a guinness world record
# -- 550 QPS: 3.2729452186773904 q:which vitamins are leached out when the foods they contain are cooked in liquid
# -- 600 QPS: 3.232968119113775 q:what is a superscript
# -- 650 QPS: 3.2519126232378412 q:what does ftd stand for flowers
# -- 700 QPS: 3.2559531038376517 q:types candy coated licorice
# -- 750 QPS: 3.20391835055831 q:world's largest ikea store
# -- 800 QPS: 3.1902367753586187 q:labradoodle price range
# -- 850 QPS: 3.170904814979475 q:what is autonomic regulation
# -- 900 QPS: 3.1360993848440843 q:when was germany divided wwii
# -- 950 QPS: 3.1474278460946357 q:what is below rib cage
# Random search complete
# 0.1616238845507613 {'mrr100': 0.1616238845507613, 'title_boost': 6.920995887386965, 'body_boost': 8.32669394613553, 'title_pf_boost': 7.663800121384759, 'body_pf_boost': 9.547532701390164, 'title_pf2_boost': 1.8072493028756242, 'body_pf2_boost': 4.3011090712505275, 'tie': 0.363984490996925, 'mm': 26.166670244332945, 'k1_title': 2.386858019383096, 'b_title': 2.1074181923784128, 'k1_body': 1.6754716666814335, 'b_body': 0.457168714748587, 'prediction': 9.805251907461568e-09, 'std_dev': 0.9999999999999989, 'opportunity': -1.412440460503675, 'prob_of_improvement': 0.07891015507694671}
# 13
# CURRENT RESULTS
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 2     4.431765    2.884621        7.415769       3.293152         4.505541
# 2     7.699919    3.572103        3.609991       5.200210         4.540570
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 1     8.655626    6.004394        2.991956       6.085950         5.097607
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 0     8.231969    8.310064        3.223559       2.288182         1.316251
# 3     6.920996    8.326694        7.663800       9.547533         1.807249
# 0     2.802984    3.351903        5.546569       1.834426         8.073953
# 1     0.513954    1.498232        4.719863       3.006974         5.486878
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 3     1.399232    3.391308        6.524227       0.270131         4.398592
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 2        0.556615  0.750314  86.256875  0.324273  1.877960  1.902642
# 2        7.178768  0.090383  59.637596  0.521740  0.816092  1.189236
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830
# 1        9.496163  0.212207  59.139499  0.775124  1.127936  2.479405
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360
# 0        8.560379  0.165337  81.438655  2.484507  0.787729  1.990831
# 3        4.301109  0.363984  26.166670  2.386858  2.107418  1.675472
# 0        1.924414  0.716069  86.624643  1.050007  2.257546  2.012478
# 1        5.194726  0.590494  82.452931  1.968564  1.110398  2.619814
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451
# 3        6.166562  0.864784  89.674619  0.867954  0.457633  2.359540
#
#      b_body    mrr100
# 2  1.853077  0.215563
# 2  1.699714  0.212440
# 3  0.911157  0.212266
# 1  0.243869  0.211603
# 4  0.324970  0.209227
# 1  2.684080  0.206245
# 2  2.678514  0.198330
# 0  0.941007  0.178180
# 3  0.457169  0.161624
# 0  0.339866  0.159195
# 1  1.148325  0.127479
# 0  0.654765  0.118431
# 3  0.534347  0.109917
# WORST QUERIES
# query
# what does prefix un mean                       8.0
# how long does adderall ir last                 8.0
# cost to replace a sump pump                    8.0
# cost to resurface a tennis court               8.0
# who acquired intelligent document solutions    8.0
# descent with modification                      8.0
# where is cvirte.dll located                    8.0
# function of skin cells                         8.0
# what is another word for pen name              8.0
# highest nba salary                             8.0
# Name: reciprical_rank, dtype: float64
# BEST QUERIES
# query
# act test definition                                     0.0
# what is an assignee on life insurance                   0.0
# what is an epaulement                                   0.0
# what is an example of an adverb                         0.0
# what is an ima                                          0.0
# what is an insurance affidavit                          0.0
# what is an irony                                        0.0
# what is an rt                                           0.0
# what is an rtc module                                   0.0
# what is angkor wat, located in present-day cambodia?    0.0
# Name: reciprical_rank, dtype: float64
#     title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 31     8.259768    7.958856        7.246220       8.211492         1.143120
# 29     9.978893    0.403252        3.716463       7.194546         3.411107
# 82     6.848113    4.011696        5.560428       3.476368         0.604789
# 95     6.485887    4.197653        3.981642       0.961739         6.769310
#
#     body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 31        3.045855  0.176278  26.834374  1.696791  2.799309  1.341413
# 29        8.843299  0.255091  61.436464  0.614038  0.527454  1.428470
# 82        8.252008  0.791257  58.898323  2.212940  1.120908  0.996990
# 95        6.610240  0.985878  85.993687  1.427240  2.451965  0.659904
#
#       b_body    prediction   std_dev  opportunity  prob_of_improvement
# 31  2.920530  1.874116e-04  0.999999    -1.415375             0.078479
# 29  2.835445  1.826784e-07  1.000000    -1.415562             0.078452
# 82  1.007995  1.158814e-07  1.000000    -1.415562             0.078452
# 95  2.037688  1.057586e-08  1.000000    -1.415563             0.078452
# /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GaussianProcessRegressor was fitted without feature names
#   warnings.warn(
# -- 50 QPS: 3.213743931644558 q:what nationality is the name d'elia
# -- 100 QPS: 3.1476773512753975 q:what does beat feet mean
# -- 150 QPS: 3.312718412387932 q:allsports physiotherapy cost of appointment
# -- 200 QPS: 3.3830229369685703 q:can you measure adh levels
# -- 250 QPS: 3.311810703523716 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.24598526149991 q:in medical terms what does htn stand for
# -- 350 QPS: 3.2364002909461416 q:is nugenix harmful
# -- 400 QPS: 3.25888950535427 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2903826965182152 q:how to find mean of grouped data
# -- 500 QPS: 3.323171065139076 q:what makes a guinness world record
# -- 550 QPS: 3.3041492333162648 q:what is a layperson
# -- 600 QPS: 3.263985888259655 q:what is a superscript
# -- 650 QPS: 3.287493465050761 q:where is dhabeji in pakistan
# -- 700 QPS: 3.2767222993648297 q:types candy coated licorice
# -- 750 QPS: 3.207969235463867 q:what was the purpose of the treaty of ghent
# -- 800 QPS: 3.199683165773183 q:labradoodle price range
# -- 850 QPS: 3.183954368815989 q:how long are flights from new york to london
# -- 900 QPS: 3.1442902749666763 q:causes of both feet numbness
# -- 950 QPS: 3.1522751963732647 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.18595004776084728 {'mrr100': 0.18595004776084728, 'title_boost': 8.259768419176638, 'body_boost': 7.958856344610554, 'title_pf_boost': 7.246220198764796, 'body_pf_boost': 8.2114915383292, 'title_pf2_boost': 1.1431204111739335, 'body_pf2_boost': 3.0458547167881367, 'tie': 0.1762776218835116, 'mm': 26.834373513364014, 'k1_title': 1.6967905141101314, 'b_title': 2.799309422408706, 'k1_body': 1.3414126730202123, 'b_body': 2.920530280252225, 'prediction': 0.00018741160684417505, 'std_dev': 0.9999993277171463, 'opportunity': -1.4153751545224846, 'prob_of_improvement': 0.07847912573505524}
# -- 50 QPS: 3.3440986183730934 q:what nationality is the name d'elia
# -- 100 QPS: 3.167310647159009 q:what does beat feet mean
# -- 150 QPS: 3.324870334579818 q:most common language in india
# -- 200 QPS: 3.375819852381461 q:can you measure adh levels
# -- 250 QPS: 3.2898475995447307 q:what is the name meaning of ammon
# -- 300 QPS: 3.2446956406406016 q:symptoms of a vaginal yeast infection
# -- 350 QPS: 3.232304345351762 q:is rheumatoid arthritis same as arthritis
# -- 400 QPS: 3.255857829011381 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.280585366219352 q:where do woodpeckers live
# -- 500 QPS: 3.312040333669136 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.2893514311362906 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.2663415979217634 q:biggest fish market in the world
# -- 650 QPS: 3.273552531892012 q:when an atom gains or loses a valence electron it becomes a charged particle called
# -- 700 QPS: 3.27518969454211 q:types candy coated licorice
# -- 750 QPS: 3.2070022651027124 q:what was the purpose of the treaty of ghent
# -- 800 QPS: 3.194424530224776 q:what river flows through pine falls
# -- 850 QPS: 3.179269942129722 q:what is autonomic regulation
# -- 900 QPS: 3.149393529624472 q:causes of ostomy drainage
# -- 950 QPS: 3.13639292667181 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.18790483984128994 {'mrr100': 0.18790483984128994, 'title_boost': 9.978893458455154, 'body_boost': 0.4032521654667509, 'title_pf_boost': 3.716463294174389, 'body_pf_boost': 7.19454555298144, 'title_pf2_boost': 3.411106726536335, 'body_pf2_boost': 8.84329878150327, 'tie': 0.2550910107447636, 'mm': 61.4364635083258, 'k1_title': 0.6140380983872782, 'b_title': 0.5274537711522161, 'k1_body': 1.428470014090276, 'b_body': 2.835445310632827, 'prediction': 1.826784116943529e-07, 'std_dev': 0.9999999999996444, 'opportunity': -1.4155623834509172, 'prob_of_improvement': 0.07845183569465644}
# -- 50 QPS: 3.27892361266301 q:what nationality is the name d'elia
# -- 100 QPS: 3.1518134662357795 q:quarter hours equal semester hours
# -- 150 QPS: 3.2785518137804104 q:what pokemon do you get in omega ruby
# -- 200 QPS: 3.370151219701036 q:what is rras
# -- 250 QPS: 3.3001969958541997 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.2494662389520723 q:symptoms of a vaginal yeast infection
# -- 350 QPS: 3.2370956935689468 q:is nugenix harmful
# -- 400 QPS: 3.2619345658187826 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.281834433906088 q:do you keep olive oil in the refrigerator
# -- 500 QPS: 3.316590876731268 q:who was us president during the early years of world war ii?
# -- 550 QPS: 3.2863174706135125 q:what is a substitute for cream of tartar
# -- 600 QPS: 3.2563638026180874 q:biggest fish market in the world
# -- 650 QPS: 3.273594791840534 q:what does ftd stand for flowers
# -- 700 QPS: 3.281659569071091 q:how does the international space station orbits the earth
# -- 750 QPS: 3.221994530103152 q:what does the term buttercup mean
# -- 800 QPS: 3.204178308329712 q:labradoodle price range
# -- 850 QPS: 3.198204626255935 q:what is autonomic regulation
# -- 900 QPS: 3.1448947442968955 q:causes of ostomy drainage
# -- 950 QPS: 3.135808250817003 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.2130670026989734 {'mrr100': 0.2130670026989734, 'title_boost': 6.8481133918478445, 'body_boost': 4.011696347437324, 'title_pf_boost': 5.5604280300789535, 'body_pf_boost': 3.4763679576485673, 'title_pf2_boost': 0.6047890174279258, 'body_pf2_boost': 8.25200800194002, 'tie': 0.791256503948909, 'mm': 58.89832292460532, 'k1_title': 2.2129396828939467, 'b_title': 1.1209076684885928, 'k1_body': 0.9969903088615046, 'b_body': 1.0079947160215876, 'prediction': 1.1588140478710799e-07, 'std_dev': 0.9999999999998512, 'opportunity': -1.415562450247924, 'prob_of_improvement': 0.07845182591008432}
# -- 50 QPS: 3.2836393645523194 q:what nationality is the name d'elia
# -- 100 QPS: 3.187630768567684 q:quarter hours equal semester hours
# -- 150 QPS: 3.334730668852638 q:how many seats one candidate can contest
# -- 200 QPS: 3.3754663473095876 q:types of durable medical equipment
# -- 250 QPS: 3.2907653998659576 q:where do bot fly live
# -- 300 QPS: 3.252872061039782 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.229966548055199 q:what happens low mean platelet volume
# -- 400 QPS: 3.262173630206945 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.2887517755490654 q:do you keep olive oil in the refrigerator
# -- 500 QPS: 3.3113041868562174 q:how much does it cost for a license plate
# -- 550 QPS: 3.2952917390641008 q:what is a layperson
# -- 600 QPS: 3.2664293452857414 q:what are buprenorphine
# -- 650 QPS: 3.2764360161460515 q:where is dhabeji in pakistan
# -- 700 QPS: 3.2690434625825486 q:how does the international space station orbits the earth
# -- 750 QPS: 3.214191805358414 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.2000131936542773 q:is the marines part of the navy?
# -- 850 QPS: 3.1719864575545764 q:how to how to get accreditation
# -- 900 QPS: 3.1322911953653048 q:causes of both feet numbness
# -- 950 QPS: 3.1431137395012123 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.20301614642629756 {'mrr100': 0.20301614642629756, 'title_boost': 6.4858873661108305, 'body_boost': 4.1976532379025455, 'title_pf_boost': 3.9816417498843104, 'body_pf_boost': 0.9617386385712445, 'title_pf2_boost': 6.769309609107524, 'body_pf2_boost': 6.610240362849725, 'tie': 0.9858779994554903, 'mm': 85.99368688570378, 'k1_title': 1.427240480973281, 'b_title': 2.4519651123718105, 'k1_body': 0.6599044696573042, 'b_body': 2.037688469325286, 'prediction': 1.057585800015053e-08, 'std_dev': 0.9999999999999988, 'opportunity': -1.4155625555534708, 'prob_of_improvement': 0.07845181048466153}
# 17
# CURRENT RESULTS
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 2     4.431765    2.884621        7.415769       3.293152         4.505541
# 2     6.848113    4.011696        5.560428       3.476368         0.604789
# 2     7.699919    3.572103        3.609991       5.200210         4.540570
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 1     8.655626    6.004394        2.991956       6.085950         5.097607
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 3     6.485887    4.197653        3.981642       0.961739         6.769310
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 1     9.978893    0.403252        3.716463       7.194546         3.411107
# 0     8.259768    7.958856        7.246220       8.211492         1.143120
# 0     8.231969    8.310064        3.223559       2.288182         1.316251
# 3     6.920996    8.326694        7.663800       9.547533         1.807249
# 0     2.802984    3.351903        5.546569       1.834426         8.073953
# 1     0.513954    1.498232        4.719863       3.006974         5.486878
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 3     1.399232    3.391308        6.524227       0.270131         4.398592
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 2        0.556615  0.750314  86.256875  0.324273  1.877960  1.902642
# 2        8.252008  0.791257  58.898323  2.212940  1.120908  0.996990
# 2        7.178768  0.090383  59.637596  0.521740  0.816092  1.189236
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830
# 1        9.496163  0.212207  59.139499  0.775124  1.127936  2.479405
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639
# 3        6.610240  0.985878  85.993687  1.427240  2.451965  0.659904
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360
# 1        8.843299  0.255091  61.436464  0.614038  0.527454  1.428470
# 0        3.045855  0.176278  26.834374  1.696791  2.799309  1.341413
# 0        8.560379  0.165337  81.438655  2.484507  0.787729  1.990831
# 3        4.301109  0.363984  26.166670  2.386858  2.107418  1.675472
# 0        1.924414  0.716069  86.624643  1.050007  2.257546  2.012478
# 1        5.194726  0.590494  82.452931  1.968564  1.110398  2.619814
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451
# 3        6.166562  0.864784  89.674619  0.867954  0.457633  2.359540
#
#      b_body    mrr100
# 2  1.853077  0.215563
# 2  1.007995  0.213067
# 2  1.699714  0.212440
# 3  0.911157  0.212266
# 1  0.243869  0.211603
# 4  0.324970  0.209227
# 1  2.684080  0.206245
# 3  2.037688  0.203016
# 2  2.678514  0.198330
# 1  2.835445  0.187905
# 0  2.920530  0.185950
# 0  0.941007  0.178180
# 3  0.457169  0.161624
# 0  0.339866  0.159195
# 1  1.148325  0.127479
# 0  0.654765  0.118431
# 3  0.534347  0.109917
# WORST QUERIES
# query
# what does the angel number 1132 mean                       12.0
# causes of pseudohypoparathyroidism                         12.0
# who acquired intelligent document solutions                12.0
# what is mapreduce                                          12.0
# population of white plains                                 12.0
# recognition forensic science definition                    12.0
# what is vmsafe                                             12.0
# how many types of dances are there                         12.0
# what was gifford pinchot founder of                        12.0
# the index of refraction for red light in water is 1.331    12.0
# Name: reciprical_rank, dtype: float64
# BEST QUERIES
# query
# act test definition                  0.0
# what is an acda fine                 0.0
# what is an applied degree program    0.0
# what is an epaulement                0.0
# what is an example of an adverb      0.0
# what is an ima                       0.0
# what is an insurance affidavit       0.0
# what is an irony                     0.0
# what is an rt                        0.0
# what is an rtc module                0.0
# Name: reciprical_rank, dtype: float64
#     title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# ...
# -- 700 QPS: 3.0418144583356987 q:who invented the first steam engine what year
# -- 750 QPS: 2.9874212745159348 q:what does the term buttercup mean
# -- 800 QPS: 2.9765226418436512 q:labradoodle price range
# -- 850 QPS: 2.9665914235542323 q:how to how to get accreditation
# -- 900 QPS: 2.9401152014934593 q:causes of both feet numbness
# -- 950 QPS: 2.949790978975591 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.18836443295724167 {'mrr100': 0.18836443295724167, 'title_boost': 1.4376726776884674, 'body_boost': 1.3327829221626009, 'title_pf_boost': 0.3884967812711626, 'body_pf_boost': 5.061150182044777, 'title_pf2_boost': 2.9383234577456605, 'body_pf2_boost': 4.5796234101904, 'tie': 0.8250451672337878, 'mm': 61.62347613317206, 'k1_title': 1.4577453743791629, 'b_title': 2.324607880673902, 'k1_body': 2.118819623666917, 'b_body': 2.2939062966298445, 'prediction': 3.6160168375745385e-08, 'std_dev': 0.9999999999999614, 'opportunity': -1.4155625299691605, 'prob_of_improvement': 0.07845181423231545}
# -- 50 QPS: 3.1983720881767224 q:what nationality is the name d'elia
# -- 100 QPS: 3.115856446232099 q:quarter hours equal semester hours
# -- 150 QPS: 3.1723142659374424 q:how many seats one candidate can contest
# -- 200 QPS: 3.211230578902275 q:how much water is needed to shower in space
# -- 250 QPS: 3.131008233573899 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.109566805593807 q:what is a plantar release?
# -- 350 QPS: 3.106380249310503 q:is nugenix harmful
# -- 400 QPS: 3.13468074002368 q:weather around the state of iowa
# -- 450 QPS: 3.160308599023827 q:what is bicarbonate in blood
# -- 500 QPS: 3.199936333206429 q:does grapefruit contain potassium
# -- 550 QPS: 3.183071463691497 q:what is a layperson
# -- 600 QPS: 3.144866358964102 q:what are buprenorphine
# -- 650 QPS: 3.1668226065943212 q:what does ftd stand for flowers
# -- 700 QPS: 3.175559673339299 q:types candy coated licorice
# -- 750 QPS: 3.1253814821104617 q:what does the term buttercup mean
# -- 800 QPS: 3.125495140696229 q:what to eat after donating blood
# -- 850 QPS: 3.0953758134104943 q:how to how to get accreditation
# -- 900 QPS: 3.038292053440616 q:what is a zif socket?
# -- 950 QPS: 3.056507314912268 q:what is below rib cage
# Random search complete
# 0.14081875029597574 {'mrr100': 0.14081875029597574, 'title_boost': 3.7113375711342558, 'body_boost': 5.3235038341191165, 'title_pf_boost': 6.922308004911494, 'body_pf_boost': 3.5504274451881557, 'title_pf2_boost': 6.042357300015869, 'body_pf2_boost': 3.999990516065539, 'tie': 0.5104477185731422, 'mm': 90.75051771738757, 'k1_title': 1.489500021149022, 'b_title': 1.9415964601632152, 'k1_body': 0.6767708945125067, 'b_body': 1.677671414510718, 'prediction': 2.0124485754585126e-08, 'std_dev': 0.9999999999999963, 'opportunity': -1.415562546004843, 'prob_of_improvement': 0.07845181188337084}
# -- 50 QPS: 3.2373193951133894 q:what nationality is the name d'elia
# -- 100 QPS: 3.1196498857484842 q:quarter hours equal semester hours
# -- 150 QPS: 3.2587637249649837 q:how many seats one candidate can contest
# -- 200 QPS: 3.347213227107217 q:what is esoteric
# -- 250 QPS: 3.2622194609924167 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.20763076400318 q:meaning of name olav
# -- 350 QPS: 3.201287688417766 q:is rheumatoid arthritis same as arthritis
# -- 400 QPS: 3.2230752116224304 q:what equipment do you need to stream netflix
# -- 450 QPS: 3.242348754210787 q:how to find mean of grouped data
# -- 500 QPS: 3.278086359837181 q:what makes a guinness world record
# -- 550 QPS: 3.2511628803236206 q:which vitamins are leached out when the foods they contain are cooked in liquid
# -- 600 QPS: 3.201554012273893 q:what is a superscript
# -- 650 QPS: 3.1956913676618415 q:what does ftd stand for flowers
# -- 700 QPS: 3.1865857800672965 q:how does the international space station orbits the earth
# -- 750 QPS: 3.13206678822782 q:who is jimi hendrix sitting on at the pop festival
# -- 800 QPS: 3.1282768190601153 q:labradoodle price range
# -- 850 QPS: 3.1074382295503735 q:what is autonomic regulation
# -- 900 QPS: 3.0573734739977922 q:what is a zif socket?
# -- 950 QPS: 3.066668637766605 q:how much does it cost to advertise on radio beat
# Random search complete
# 0.13097518787390378 {'mrr100': 0.13097518787390378, 'title_boost': 3.9230793106608406, 'body_boost': 7.45434504633783, 'title_pf_boost': 4.516258679885694, 'body_pf_boost': 7.595794798848688, 'title_pf2_boost': 9.62217357837816, 'body_pf2_boost': 8.180094660546578, 'tie': 0.5598554673551033, 'mm': 79.94493321366653, 'k1_title': 1.4850557075586748, 'b_title': 2.015439548172492, 'k1_body': 0.5815331841170261, 'b_body': 2.877199330619824, 'prediction': 1.3299304547688767e-08, 'std_dev': 0.9999999999999954, 'opportunity': -1.4155625528300242, 'prob_of_improvement': 0.07845181088359893}
# 41
# CURRENT RESULTS
#    title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 2     4.431765    2.884621        7.415769       3.293152         4.505541
# 2     6.848113    4.011696        5.560428       3.476368         0.604789
# 1     8.294456    3.908109        6.345971       9.795311         8.713807
# 2     7.699919    3.572103        3.609991       5.200210         4.540570
# 3     4.431378    2.082981        4.586523       1.744414         4.911872
# 1     8.655626    6.004394        2.991956       6.085950         5.097607
# 4     8.814608    6.350059        8.092083       9.187220         6.603446
# 3     6.714551    5.052420        4.246926       1.436378         7.403890
# 0     5.782555    2.742865        4.959944       1.036898         5.759636
# 1     9.084801    6.177775        5.695773       0.557343         0.119031
# 1     1.212630    0.416821        3.640485       2.676821         2.733146
# 3     7.830323    3.383674        0.315924       0.703006         7.191726
# 3     2.187848    0.695101        7.814941       4.999673         5.472740
# 3     6.485887    4.197653        3.981642       0.961739         6.769310
# 2     9.437601    2.710573        1.769210       1.580066         4.450997
# 2     8.230876    7.449357        4.273594       2.367178         5.844811
# 2     9.648127    1.927283        3.356690       8.283395         6.904179
# 1     8.800013    2.111539        5.908966       0.367414         5.271412
# 1     1.437673    1.332783        0.388497       5.061150         2.938323
# 1     9.978893    0.403252        3.716463       7.194546         3.411107
# 0     8.259768    7.958856        7.246220       8.211492         1.143120
# 2     7.103191    7.496911        3.971804       3.820502         4.171253
# 0     8.231969    8.310064        3.223559       2.288182         1.316251
# 2     7.092395    7.529533        3.228508       3.445173         7.664461
# 0     6.684938    7.763110        3.204533       1.859375         2.693169
# 3     6.920996    8.326694        7.663800       9.547533         1.807249
# 0     2.802984    3.351903        5.546569       1.834426         8.073953
# 0     6.352505    8.236735        4.359680       2.557795         8.772559
# 2     2.324182    3.088551        4.629479       2.998502         0.744607
# 2     3.711338    5.323504        6.922308       3.550427         6.042357
# 0     5.596842    8.097842        2.892631       4.829558         8.039467
# 3     6.079399    9.249481        8.155666       5.201246         3.672331
# 3     3.923079    7.454345        4.516259       7.595795         9.622174
# 0     5.064554    8.638612        6.824506       3.241700         0.574577
# 1     0.513954    1.498232        4.719863       3.006974         5.486878
# 3     4.087776    8.131842        4.785459       4.192125         0.806251
# 0     1.285730    2.917797        6.824778       2.687833         5.062555
# 1     0.739914    3.369364        6.441796       2.451734         3.557654
# 0     2.462362    8.775352        7.193315       2.148689         0.429236
# 1     0.683153    3.487791        0.617062       1.933361         2.904287
# 3     1.399232    3.391308        6.524227       0.270131         4.398592
#
#    body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 2        0.556615  0.750314  86.256875  0.324273  1.877960  1.902642
# 2        8.252008  0.791257  58.898323  2.212940  1.120908  0.996990
# 1        4.821061  0.976793  62.617601  1.551031  1.474852  1.292976
# 2        7.178768  0.090383  59.637596  0.521740  0.816092  1.189236
# 3        2.578916  0.830334  86.209159  1.674380  1.924115  2.265830
# 1        9.496163  0.212207  59.139499  0.775124  1.127936  2.479405
# 4        3.617847  0.139966  26.336642  2.405985  1.290006  2.983328
# 3        4.448212  0.458303  89.471705  2.873770  1.891558  2.641453
# 0        1.618155  0.031399  84.172305  2.537580  0.423245  0.967762
# 1        6.363155  0.757364  80.996183  1.086941  1.058246  1.580639
# 1        8.365665  0.126583  62.968004  1.662625  2.801869  2.426819
# 3        4.617807  0.306499  89.728947  1.545884  0.154956  2.926389
# 3        0.168750  0.836894  82.894430  2.073872  2.552337  2.452069
# 3        6.610240  0.985878  85.993687  1.427240  2.451965  0.659904
# 2        5.033633  0.198934  59.887811  1.403754  2.525750  1.643942
# 2        2.989199  0.864335  81.244587  1.505150  2.157793  1.541625
# 2        5.066393  0.922657  63.651684  0.717177  0.656514  1.609360
# 1        2.003193  0.585742  82.021093  0.323248  1.226186  0.911428
# 1        4.579623  0.825045  61.623476  1.457745  2.324608  2.118820
# 1        8.843299  0.255091  61.436464  0.614038  0.527454  1.428470
# 0        3.045855  0.176278  26.834374  1.696791  2.799309  1.341413
# 2        7.108038  0.287499  57.077079  1.773642  2.074275  0.574972
# 0        8.560379  0.165337  81.438655  2.484507  0.787729  1.990831
# 2        8.395019  0.998298  84.962536  0.325508  1.646388  1.404541
# 0        4.652563  0.474489  82.333450  2.847788  0.467027  0.922427
# 3        4.301109  0.363984  26.166670  2.386858  2.107418  1.675472
# 0        1.924414  0.716069  86.624643  1.050007  2.257546  2.012478
# 0        9.290465  0.961638  80.686606  1.744588  0.365082  0.189192
# 2        8.467726  0.424138  60.570017  0.668802  1.116322  1.944807
# 2        3.999991  0.510448  90.750518  1.489500  1.941596  0.676771
# 0        9.783770  0.452650  83.546767  1.817072  2.788651  0.417285
# 3        3.209430  0.649955  25.173083  0.465556  2.538267  1.752271
# 3        8.180095  0.559855  79.944933  1.485056  2.015440  0.581533
# 0        8.431171  0.286477  61.376990  1.395698  0.118931  0.388486
# 1        5.194726  0.590494  82.452931  1.968564  1.110398  2.619814
# 3        7.339292  0.152600  59.066851  2.930234  2.661453  0.243679
# 0        5.438448  0.880323  80.493911  1.201893  2.715234  1.695004
# 1        7.235456  0.664268  62.086337  2.642105  1.267845  1.948486
# 0        4.038839  0.569924  81.503925  2.622682  0.480494  0.557451
# 1        7.463144  0.403515  63.315710  0.888232  1.919665  1.076834
# 3        6.166562  0.864784  89.674619  0.867954  0.457633  2.359540
#
#      b_body    mrr100
# 2  1.853077  0.215563
# 2  1.007995  0.213067
# 1  0.731703  0.213021
# 2  1.699714  0.212440
# 3  0.911157  0.212266
# 1  0.243869  0.211603
# 4  0.324970  0.209227
# 3  0.120001  0.208556
# 0  0.241592  0.208472
# 1  2.684080  0.206245
# 1  1.119079  0.205174
# 3  1.229342  0.204880
# 3  0.474885  0.204860
# 3  2.037688  0.203016
# 2  1.833854  0.200428
# 2  1.877414  0.198611
# 2  2.678514  0.198330
# 1  1.685453  0.193239
# 1  2.293906  0.188364
# 1  2.835445  0.187905
# 0  2.920530  0.185950
# 2  0.782071  0.183410
# 0  0.941007  0.178180
# 2  2.861146  0.175629
# 0  2.634784  0.163760
# 3  0.457169  0.161624
# 0  0.339866  0.159195
# 0  1.300255  0.148658
# 2  1.285130  0.144677
# 2  1.677671  0.140819
# 0  2.691687  0.139915
# 3  2.493864  0.139760
# 3  2.877199  0.130975
# 0  2.212606  0.128788
# 1  1.148325  0.127479
# 3  1.844275  0.126290
# 0  2.121670  0.124689
# 1  2.958284  0.123467
# 0  0.654765  0.118431
# 1  0.805250  0.116384
# 3  0.534347  0.109917
# WORST QUERIES
# query
# what does the angel number 1132 mean                                                   36.0
# what is another word for pen name                                                      36.0
# what is dicom conformance statement                                                    36.0
# when an atom gains or loses a valence electron it becomes a charged particle called    36.0
# cost to resurface a tennis court                                                       36.0
# what does ftd stand for flowers                                                        36.0
# what is silica in toothpaste                                                           36.0
# population of white plains                                                             36.0
# who acquired intelligent document solutions                                            36.0
# recognition forensic science definition                                                36.0
# Name: reciprical_rank, dtype: float64
# BEST QUERIES
# query
# what cheese is low carb              0.0
# what is a woo woo                    0.0
# what is a zif socket?                0.0
# what is adverbs                      0.0
# what is aerobic exercise?            0.0
# what is an acda fine                 0.0
# what is an applied degree program    0.0
# what is an epaulement                0.0
# what is an example of an adverb      0.0
# what is an ima                       0.0
# Name: reciprical_rank, dtype: float64
#     title_boost  body_boost  title_pf_boost  body_pf_boost  title_pf2_boost  \
# 61     0.273775    4.104636        6.110643       3.535118         0.715412
# 52     2.762110    1.163286        4.631968       4.697081         4.548072
# 89     2.601854    9.579275        1.879063       8.672540         6.902638
# 20     7.446351    0.692231        7.555658       8.157341         5.064694
#
#     body_pf2_boost       tie         mm  k1_title   b_title   k1_body  \
# 61        8.006081  0.708132  61.973412  2.600339  1.737459  2.604051
# 52        7.960561  0.851762  60.645225  2.276452  1.364305  0.751153
# 89        9.046195  0.515947  80.581847  2.857507  1.524912  2.712766
# 20        6.225156  0.910375  65.139140  0.107361  1.168082  0.803328
#
#       b_body    prediction  std_dev  opportunity  prob_of_improvement
# 61  0.390459  8.322343e-05      1.0    -1.415479             0.078464
# 52  0.637699  2.611366e-06      1.0    -1.415560             0.078452
# 89  1.824647  2.820388e-08      1.0    -1.415563             0.078452
# 20  2.456398  1.943989e-08      1.0    -1.415563             0.078452
# /Users/douglas.turnbull/ws/msmarco/venv/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GaussianProcessRegressor was fitted without feature names
#   warnings.warn(
# -- 50 QPS: 3.226407552152541 q:what nationality is the name d'elia
# -- 100 QPS: 3.1218681971402686 q:quarter hours equal semester hours
# -- 150 QPS: 3.2609627034869217 q:allsports physiotherapy cost of appointment
# -- 200 QPS: 3.3461804564120374 q:what is esoteric
# -- 250 QPS: 3.24946774977434 q:what iron-containing compound carries oxygen in the bloodstream
# -- 300 QPS: 3.220574543146691 q:what does it mean for a result to be statistically significant?
# -- 350 QPS: 3.204348936282106 q:what makes infection around teeth
# -- 400 QPS: 3.23210391175507 q:why is the holocaust unique
# -- 450 QPS: 3.2551608975571615 q:how to find mean of grouped data
# -- 500 QPS: 3.272820121139036 q:what makes a guinness world record
# -- 550 QPS: 3.219304906428084 q:which vitamins are leached out when the foods they contain are cooked in liquid
# -- 600 QPS: 3.160900376703354 q:biggest fish market in the world
# -- 650 QPS: 3.1666184379512194 q:what does ftd stand for flowers
# -- 700 QPS: 3.1578029723980165 q:how does the international space station orbits the earth
